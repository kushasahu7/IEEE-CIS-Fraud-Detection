# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from keras.callbacks import ReduceLROnPlateau
from keras.layers import Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from keras.optimizers import RMSprop
from keras.utils import to_categorical
from keras_preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

from keras.models import Sequential
import tensorflow as tf

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# Num GPUs Available:  1

# %%
train_identity_data = pd.read_csv('./data/train_identity.csv')
train_transaction_data = pd.read_csv('./data/train_transaction.csv')

# %%
train_identity_data[0:10]
# Out:
#    TransactionID  id_01     id_02  id_03  id_04  id_05  id_06  id_07  id_08  \
# 0        2987004    0.0   70787.0    NaN    NaN    NaN    NaN    NaN    NaN
# 1        2987008   -5.0   98945.0    NaN    NaN    0.0   -5.0    NaN    NaN
# 2        2987010   -5.0  191631.0    0.0    0.0    0.0    0.0    NaN    NaN
# 3        2987011   -5.0  221832.0    NaN    NaN    0.0   -6.0    NaN    NaN
# 4        2987016    0.0    7460.0    0.0    0.0    1.0    0.0    NaN    NaN
# 5        2987017   -5.0   61141.0    3.0    0.0    3.0    0.0    NaN    NaN
# 6        2987022  -15.0       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7        2987038    0.0   31964.0    0.0    0.0    0.0  -10.0    NaN    NaN
# 8        2987040  -10.0  116098.0    0.0    0.0    0.0    0.0    NaN    NaN
# 9        2987048   -5.0  257037.0    NaN    NaN    0.0    0.0    NaN    NaN
#
#    id_09  ...                id_31  id_32      id_33           id_34  id_35  \
# ...

# %%
train_transaction_data[0:10]
# Out:
#    TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  card1  \
# 0        2987000        0          86400            68.5         W  13926
# 1        2987001        0          86401            29.0         W   2755
# 2        2987002        0          86469            59.0         W   4663
# 3        2987003        0          86499            50.0         W  18132
# 4        2987004        0          86506            50.0         H   4497
# 5        2987005        0          86510            49.0         W   5937
# 6        2987006        0          86522           159.0         W  12308
# 7        2987007        0          86529           422.5         W  12695
# 8        2987008        0          86535            15.0         H   2803
# 9        2987009        0          86536           117.0         W  17399
#
#    card2  card3       card4  card5  ... V330  V331  V332  V333  V334 V335  \
# 0    NaN  150.0    discover  142.0  ...  NaN   NaN   NaN   NaN   NaN  NaN
# ...

# %%
test_identity_data = pd.read_csv('./data/test_identity.csv')
test_transaction_data = pd.read_csv('./data/test_transaction.csv')

train_data = train_transaction_data.merge(train_identity_data)
test_data = test_transaction_data.merge(test_identity_data)

# %%
train_data.isnull().sum()
# Out:
# TransactionID         0
# isFraud               0
# TransactionDT         0
# TransactionAmt        0
# ProductCD             0
#                   ...
# id_36              3248
# id_37              3248
# id_38              3248
# DeviceType         3423
# DeviceInfo        25567
# Length: 434, dtype: int64

# %%
test_data.isnull().sum()
# Out:
# TransactionID         0
# TransactionDT         0
# TransactionAmt        0
# ProductCD             0
# card1                 0
#                   ...
# id-36              4930
# id-37              4930
# id-38              4930
# DeviceType         4976
# DeviceInfo        26850
# Length: 433, dtype: int64

# %%
print("data", train_data.shape, test_data.shape)
# Out:
# data (144233, 434) (141907, 433)

# %%
is_fraud_label = train_data["isFraud"]

# %%
is_fraud_label.value_counts()
# Out:
# isFraud
# 0    132915
# 1     11318
# Name: count, dtype: int64

# %%
c
